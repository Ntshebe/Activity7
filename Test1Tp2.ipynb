# %% [markdown]
# <a href="https://colab.research.google.com/github/Ntshebe/Activity7/blob/master/Test1Tp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mr M Ntshangase
#
# 22341705
#
# Mr T Mbuthuma
#
# 22329027
#
# Mr MS Khanyile
#
# 22354752
#
# Git hub Account: Ntshebe

# %% [markdown]
# **DATA SOURCING**
#
# The link:
# *   https://www.kaggle.com/datasets/rkiattisak/traveler-trip-data?select=Travel+details+dataset.csv
#
# 1)Completeness: The dataset includes key fields such as destination, traveler demographics, travel dates, costs, and transportation types, which are essential for tourism analysis.
#
# 2)Relevance: It aligns with the theme of tourism and provides sufficient data points to analyze travel patterns, costs, and preferences.
#
# 3)Credibility: The dataset is sourced from a reliable platform (Kaggle), ensuring its authenticity and accuracy.

# %% [markdown]
# **LIFE CYCLE**
#
# The Machine Learning Project Lifecycle is a structured approach that guides the successful completion of machine learning projects. It consists of various stages, from understanding the problem to deploying the model. Here’s an explanation of each phase
#
# **1)Objective Defination**
# --Clearly articulate the problem you're solving and the goals of the project. For instance, in our project, it might be analyzing tourism data for trends and insights.
#
# **2)Data Collection**
# --This involves acquiring raw data from reliable sources.
#
# **3)Data Cleaning**
# -- Preparing the data for analysis by handling missing values, fixing inconsistencies, removing duplicates, and ensuring the data is complete and accurate.
#
# **4)Data Mining**
# -- Extracting patterns or relationships in the dataset using techniques like clustering, classification, or anomaly detection.
#
#
# **5)Data Visualization**
# --Creating visual representations of the data, like scatter plots, histograms, or bar charts, to communicate insights effectively.
#
# **6)Statistical Analysis**
# --Applying statistical methods to interpret the data, such as calculating means, medians, correlations, and other metrics, to support your conclusions.

# %% [markdown]
# This is the link to our video : https://youtu.be/tNx1d6RGQYw

# %% [markdown]
# **DATA UNDERSTANDING**

# %% [markdown]
# Importing all packages that will be needed to project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now i'm loading my dataset called Travel details to the data frame called 'df'.

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/Travel details dataset.csv')

# %% [markdown]
# Now i'm printing the first 5 rows

# %%
df.head()
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK   5/1/2023   5/8/2023              7.0
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3        4     New York, USA  8/15/2023  8/29/2023             14.0
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023              7.0
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith          35.0            Male             American
# 1       Jane Doe          28.0          Female             Canadian
# 2      David Lee          45.0            Male               Korean
# 3  Sarah Johnson          29.0          Female              British
# 4     Kim Nguyen          26.0          Female           Vietnamese
#
#   Accommodation type Accommodation cost Transportation type  \
# 0              Hotel               1200              Flight
# ...

# %% [markdown]
# Printing the last first rows on my datasets

# %%
df.tail()
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 134      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023  9/22/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023  10/8/2023              7.0
#
#        Traveler name  Traveler age Traveler gender Traveler nationality  \
# 134       Jose Perez          37.0            Male            Brazilian
# 135      Emma Wilson          29.0          Female             Canadian
# 136        Ryan Chen          34.0            Male              Chinese
# 137  Sofia Rodriguez          25.0          Female              Spanish
# 138    William Brown          39.0            Male        New Zealander
#
#     Accommodation type Accommodation cost Transportation type  \
# ...

# %% [markdown]
# Provide the summary of the dataset's structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Trip ID               139 non-null    int64
#  1   Destination           137 non-null    object
#  2   Start date            137 non-null    object
#  3   End date              137 non-null    object
#  4   Duration (days)       137 non-null    float64
#  5   Traveler name         137 non-null    object
#  6   Traveler age          137 non-null    float64
#  7   Traveler gender       137 non-null    object
#  8   Traveler nationality  137 non-null    object
#  9   Accommodation type    137 non-null    object
#  10  Accommodation cost    137 non-null    object
#  11  Transportation type   136 non-null    object
#  12  Transportation cost   136 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 14.2+ KB

# %% [markdown]
# calcute the statistical summary for numeric culomns in a dataset

# %%
df.describe()
# Out:
#           Trip ID  Duration (days)  Traveler age
# count  139.000000       137.000000    137.000000
# mean    70.000000         7.605839     33.175182
# std     40.269923         1.601276      7.145441
# min      1.000000         5.000000     20.000000
# 25%     35.500000         7.000000     28.000000
# 50%     70.000000         7.000000     31.000000
# 75%    104.500000         8.000000     38.000000
# max    139.000000        14.000000     60.000000

# %% [markdown]
# **Shape**
#
# I'm printing the total number of rows and columns in a dataset

# %%
df.shape
# Out:
# (139, 13)

# %% [markdown]
# **Size**
#
# I'm printing the number of elements in a dataset

# %%
df.size
# Out:
# 1807

# %% [markdown]
# **dtypes**
#
# Now i'm print the data type for each column in a dataset

# %%
df.dtypes
# Out:
# Trip ID                   int64
# Destination              object
# Start date               object
# End date                 object
# Duration (days)         float64
# Traveler name            object
# Traveler age            float64
# Traveler gender          object
# Traveler nationality     object
# Accommodation type       object
# Accommodation cost       object
# Transportation type      object
# Transportation cost      object
# dtype: object

# %% [markdown]
# **Columns**
#
# Now i'm printing the exact columns name.

# %%
df.columns
# Out:
# Index(['Trip ID', 'Destination', 'Start date', 'End date', 'Duration (days)',
#        'Traveler name', 'Traveler age', 'Traveler gender',
#        'Traveler nationality', 'Accommodation type', 'Accommodation cost',
#        'Transportation type', 'Transportation cost'],
#       dtype='object')

# %% [markdown]
# **Index**
#
# Printing the default index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=139, step=1)

# %% [markdown]
# ** Visualized distribution**

# %%
numeric_columns = df.select_dtypes(include='number').columns
for col in numeric_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# **2) DATA CLEANING**

# %% [markdown]
# delete the repeated data

# %%
df.drop_duplicates()
df
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 0          1              London, UK   5/1/2023   5/8/2023              7.0
# 1          2        Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2          3         Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3          4           New York, USA  8/15/2023  8/29/2023             14.0
# 4          5            Tokyo, Japan  9/10/2023  9/17/2023              7.0
# ..       ...                     ...        ...        ...              ...
# 134      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023  9/22/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023  10/8/2023              7.0
#
# ...

# %% [markdown]
# Now, I'm droping the useless column

# %%
df= df.drop(['End date'], axis=1)
df
# Out:
#      Trip ID             Destination Start date  Duration (days)  \
# 0          1              London, UK   5/1/2023              7.0
# 1          2        Phuket, Thailand  6/15/2023              5.0
# 2          3         Bali, Indonesia   7/1/2023              7.0
# 3          4           New York, USA  8/15/2023             14.0
# 4          5            Tokyo, Japan  9/10/2023              7.0
# ..       ...                     ...        ...              ...
# 134      135  Rio de Janeiro, Brazil   8/1/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023              7.0
#
#        Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0         John Smith          35.0            Male             American
# ...

# %% [markdown]
# Now, I'm removing the white spaces on my columns

# %%
df['Destination']= df['Destination'].str.strip()
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Traveler nationality']= df['Traveler nationality'].str.strip()
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Accommodation type']= df['Accommodation type'].str.strip()
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Traveler name']=df['Traveler name'].str.strip()
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Transportation type']=df['Transportation type'].str.strip()
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Traveler gender']=df['Traveler gender'].str.strip()
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %% [markdown]
# Now i'm setting all mssing value on numerical columns to zero

# %%
df['Accommodation cost']= df['Transportation cost'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Duration (days)']= df['Duration (days)'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              0.0
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Transportation cost']= df['Transportation cost'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Traveler age']= df['Traveler age'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              NaN
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Start date']= df['Start date'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023              8.0
# 127      128                      NaN          0              0.0
# 128      129            Paris, France   5/1/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023              9.0
# 131      132        Sydney, Australia  6/15/2023              6.0
# 132      133              Rome, Italy   7/1/2023              7.0
# 133      134       New York City, USA  7/15/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023              7.0
# 137      138         Barcelona, Spain  9/15/2023              7.0
# 138      139    Auckland, New Zealand  10/1/2023              7.0
#
# ...

# %%
df['Trip ID']= df['Trip ID'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              0.0
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %%
df['Accommodation cost']= df['Accommodation cost'].fillna(0)
df.tail(13)
# Out:
#      Trip ID              Destination Start date   End date  Duration (days)  \
# 126      127          Bali, Indonesia  2/10/2023  2/18/2023              8.0
# 127      128                      NaN        NaN        NaN              0.0
# 128      129            Paris, France   5/1/2023   5/7/2023              6.0
# 129      130             Tokyo, Japan  5/15/2023  5/22/2023              7.0
# 130      131  Cape Town, South Africa   6/1/2023  6/10/2023              9.0
# 131      132        Sydney, Australia  6/15/2023  6/21/2023              6.0
# 132      133              Rome, Italy   7/1/2023   7/8/2023              7.0
# 133      134       New York City, USA  7/15/2023  7/22/2023              7.0
# 134      135   Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136        Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137        Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# ...

# %% [markdown]
# The number of missing values for each column

# %%
df.isnull().sum()
# Out:
# Trip ID                 0
# Destination             2
# Start date              2
# End date                2
# Duration (days)         0
# Traveler name           2
# Traveler age            2
# Traveler gender         2
# Traveler nationality    2
# Accommodation type      2
# Accommodation cost      0
# Transportation type     3
# Transportation cost     3
# dtype: int64

# %% [markdown]
# Now i want to display the percentage of the missing values for each column in a dataset

# %%
for column in df.columns:
  percentage = df[column].isnull().mean()
  print(f"{column}: {percentage:.2%}")
# Out:
# Trip ID: 0.00%
# Destination: 1.44%
# Start date: 1.44%
# End date: 1.44%
# Duration (days): 0.00%
# Traveler name: 1.44%
# Traveler age: 1.44%
# Traveler gender: 1.44%
# Traveler nationality: 1.44%
# Accommodation type: 1.44%
# Accommodation cost: 0.00%
# Transportation type: 2.16%
# Transportation cost: 2.16%

# %% [markdown]
# **OUTLIER**

# %% [markdown]
# 1. Detecting Outliers
#  * IQR Method: Outliers are defined as data points that
#  lie below the lower bound or above the upper bound, calculated as:
#    *  Lower Bound = Q1 - 1.5 * IQR
#    *  Upper Bound = Q3 + 1.5 * IQR
#  *  Quartiles ( and ) divide the dataset into four parts, and IQR measures the spread between the middle 50% of values.
#
# 2. Removing Outliers:
#    *   Rows with values outside these bounds for the
#        selected column are removed from the dataset.
#
#
# 3.  Displaying Results:
#    *  The cleaned dataset excludes rows with outliers
#       for Accommodation cost and Transportation cost.

# %% [markdown]
# **Data Slicing**

# %% [markdown]
# WE are slicing the data

# %%
paris_data = df[df['Destination'].str.contains('Paris', na=False)]
print(paris_data)
# Out:
#      Trip ID    Destination  Start date    End date  Duration (days)  \
# 5          6  Paris, France   10/5/2023  10/10/2023              5.0
# 16        17          Paris    9/1/2023   9/10/2023              9.0
# 24        25          Paris  12/22/2023  12/28/2023              6.0
# 38        39  Paris, France   6/12/2022   6/19/2022              7.0
# 49        50  Paris, France   8/15/2023   8/22/2023              7.0
# 60        61          Paris   7/12/2022   7/18/2022              6.0
# 66        67          Paris    5/6/2024   5/12/2024              6.0
# 75        76  Paris, France    6/7/2023   6/14/2023              7.0
# 83        84          Paris   6/15/2021   6/20/2021              6.0
# 94        95          Paris   6/15/2022   6/20/2022              5.0
# 105      106          Paris   5/15/2022   5/20/2022              5.0
# 117      118  Paris, France   3/15/2022   3/22/2022              7.0
# 125      126  Paris, France  12/24/2022    1/1/2023              8.0
# ...

# %%
df['Accommodation cost'] = df['Accommodation cost'].replace('[^\d.]', '', regex=True).astype(float)

high_cost_trips = df[df['Accommodation cost'] > 1000]
print(high_cost_trips)
# Out:
#      Trip ID              Destination  Start date    End date  \
# 6          7        Sydney, Australia  11/20/2023  11/30/2023
# 12        13         Honolulu, Hawaii   6/10/2024   6/18/2024
# 63        64                   Sydney   6/23/2023   6/29/2023
# 96        97                   Sydney  11/23/2022   12/2/2022
# 101      102                Cape Town    1/6/2024   1/14/2024
# 108      109                     Bali   8/12/2022   8/20/2022
# 128      129            Paris, France    5/1/2023    5/7/2023
# 129      130             Tokyo, Japan   5/15/2023   5/22/2023
# 130      131  Cape Town, South Africa    6/1/2023   6/10/2023
# 131      132        Sydney, Australia   6/15/2023   6/21/2023
# 132      133              Rome, Italy    7/1/2023    7/8/2023
# 133      134       New York City, USA   7/15/2023   7/22/2023
# 134      135   Rio de Janeiro, Brazil    8/1/2023   8/10/2023
# 135      136        Vancouver, Canada   8/15/2023   8/21/2023
# ...

# %%
sliced_Age = df['Traveler age'] .iloc[0:5]
print(sliced_Age)
# Out:
# 0    35.0
# 1    28.0
# 2    45.0
# 3    29.0
# 4    26.0
# Name: Traveler age, dtype: float64

# %% [markdown]
# **Data Visualization**

# %%
gendercount = df['Traveler gender'].value_counts()
plt.pie(gendercount,labels=gendercount.index, autopct='%1.1f%%')
plt.title("Traveler Gender Distribution")
plt.show()

# %%
df['Accommodation cost'] = df['Accommodation cost'].replace('[^\d.]', '', regex=True).astype(float)
df['Transportation cost'] = df['Transportation cost'].replace('[^\d.]', '', regex=True).astype(float)
df['Traveler name'] = df['Traveler name'].astype(str)

df_sliced = df.iloc[0:10]

plt.figure(figsize=(10, 6))
plt.plot(df_sliced['Traveler name'], df_sliced['Accommodation cost'], label='Accommodation Cost', color='blue', marker='o', linestyle='-')
plt.plot(df_sliced['Traveler name'], df_sliced['Transportation cost'], label='Transportation Cost', color='red', marker='s', linestyle='--')
plt.xlabel("Traveler Name")
plt.ylabel("Cost ($)")
plt.title("Traveler Name vs Accommodation & Transportation Costs (First 10 Travelers)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_sliced = df.iloc[0:10]
plt.figure(figsize=(10, 6))

plt.scatter(df_sliced['Traveler name'], df_sliced['Accommodation cost'], label='Accommodation Cost', color='blue', marker='o', linestyle='-')
plt.scatter(df_sliced['Traveler name'], df_sliced['Transportation cost'], label='Transportation Cost', color='red', marker='s', linestyle='--')
plt.xlabel("Traveler Name")
plt.ylabel("Cost ($)")
plt.title("Traveler Name vs Accommodation & Transportation Costs (First 10 Travelers)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.plot(df_sliced['Traveler name'],df_sliced['Duration (days)'])
plt.xlabel("Traveler Name")
plt.ylabel("Duration (days)")
plt.title("Traveler Name vs Duration (days)")
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df_sliced['Traveler name'],df_sliced['Traveler age'])
plt.xlabel("Traveler Name")
plt.ylabel("Traveler age")
plt.title("Traveler Name vs Traveler age")
plt.xticks(rotation=45)
plt.show()

# %%
df['Accommodation cost'] = df['Accommodation cost'].replace('[^\d.]', '', regex=True).astype(float)


nationality_cost = df.groupby('Traveler nationality')['Accommodation cost'].mean()
plt.figure(figsize=(8, 8))
nationality_cost.plot(kind='pie', autopct='%1.1f%%'),
plt.title("Average Accommodation Cost by Traveler Nationality")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(df['Accommodation cost'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title("Box Plot of Accommodation Cost")
plt.xlabel("Accommodation Cost ($)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Accommodation cost'], bins=15, color='blue', alpha=0.7)
plt.title("Histogram of Accommodation Cost")
plt.xlabel("Accommodation Cost ($)")
plt.ylabel("Frequency")
plt.show()
